# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\WELCOME\Downloads\data\data_2022-Aug-24.csv")

# %%
data
# Out:
#      areaType        areaName   areaCode        date  newCasesBySpecimenDate  \
# 0    overview  United Kingdom  K02000001  2022-05-19                    6818
# 1    overview  United Kingdom  K02000001  2022-05-18                    7636
# 2    overview  United Kingdom  K02000001  2022-05-17                    8284
# 3    overview  United Kingdom  K02000001  2022-05-16                    9417
# 4    overview  United Kingdom  K02000001  2022-05-15                    7973
# ..        ...             ...        ...         ...                     ...
# 836  overview  United Kingdom  K02000001  2020-02-03                      18
# 837  overview  United Kingdom  K02000001  2020-02-02                       1
# 838  overview  United Kingdom  K02000001  2020-02-01                       0
# 839  overview  United Kingdom  K02000001  2020-01-31                       0
# 840  overview  United Kingdom  K02000001  2020-01-30                       1
#
# ...

# %%
data.columns
# Out:
# Index(['areaType', 'areaName', 'areaCode', 'date', 'newCasesBySpecimenDate',
#        'cumCasesBySpecimenDate', 'newFirstEpisodesBySpecimenDate',
#        'cumFirstEpisodesBySpecimenDate', 'newReinfectionsBySpecimenDate',
#        'cumReinfectionsBySpecimenDate'],
#       dtype='object')

# %%
new_data=data[data.columns[3:10]]

# %%
new_data.head()
# Out:
#          date  newCasesBySpecimenDate  cumCasesBySpecimenDate  \
# 0  2022-05-19                    6818                22242512
# 1  2022-05-18                    7636                22235694
# 2  2022-05-17                    8284                22228058
# 3  2022-05-16                    9417                22219774
# 4  2022-05-15                    7973                22210357
#
#    newFirstEpisodesBySpecimenDate  cumFirstEpisodesBySpecimenDate  \
# 0                            5621                        21054137
# 1                            6366                        21048516
# 2                            6900                        21042150
# 3                            7742                        21035250
# 4                            6687                        21027508
#
#    newReinfectionsBySpecimenDate  cumReinfectionsBySpecimenDate
# 0                         1197.0                      1188375.0
# 1                         1270.0                      1187178.0
# ...

# %%
type(new_data.date[0])
# Out:
# str

# %%
new_data.date=pd.to_datetime(new_data.date)
# Out:
# C:\Users\WELCOME\AppData\Local\Temp\ipykernel_10588\1654215596.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data.date=pd.to_datetime(new_data.date)

# %%
new_data.head()
# Out:
#         date  newCasesBySpecimenDate  cumCasesBySpecimenDate  \
# 0 2022-05-19                    6818                22242512
# 1 2022-05-18                    7636                22235694
# 2 2022-05-17                    8284                22228058
# 3 2022-05-16                    9417                22219774
# 4 2022-05-15                    7973                22210357
#
#    newFirstEpisodesBySpecimenDate  cumFirstEpisodesBySpecimenDate  \
# 0                            5621                        21054137
# 1                            6366                        21048516
# 2                            6900                        21042150
# 3                            7742                        21035250
# 4                            6687                        21027508
#
#    newReinfectionsBySpecimenDate  cumReinfectionsBySpecimenDate
# 0                         1197.0                      1188375.0
# 1                         1270.0                      1187178.0
# ...

# %%
new_data_2021=new_data[(new_data.date>=pd.to_datetime("2021-01-01")) & (new_data.date<=pd.to_datetime("2021-12-31"))]

# %%
new_data_2021.shape
# Out:
# (365, 7)

# %%
new_data_2021.to_csv(r"C:\Users\WELCOME\Downloads\data\covid_data_2021",index=False)
