# %%
#!pip install cufflinks

# %%
import pandas as pd
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)
import numpy as np
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
anger=pd.read_csv(r"C:\Users\WELCOME\Downloads\data\emo_dyn\Anger.csv",index_col=[0])
trust=pd.read_csv(r"C:\Users\WELCOME\Downloads\data\emo_dyn\Trust.csv",index_col=[0])
anti=pd.read_csv(r"C:\Users\WELCOME\Downloads\data\emo_dyn\Anticipation.csv",index_col=[0])
disgust=pd.read_csv(r"C:\Users\WELCOME\Downloads\data\emo_dyn\Disgust.csv",index_col=[0])
fear=pd.read_csv(r"C:\Users\WELCOME\Downloads\data\emo_dyn\Fear.csv",index_col=[0])
joy=pd.read_csv(r"C:\Users\WELCOME\Downloads\data\emo_dyn\Joy.csv",index_col=[0])
negative=pd.read_csv(r"C:\Users\WELCOME\Downloads\data\emo_dyn\Negative.csv",index_col=[0])
positive=pd.read_csv(r"C:\Users\WELCOME\Downloads\data\emo_dyn\Positive.csv",index_col=[0])
sad=pd.read_csv(r"C:\Users\WELCOME\Downloads\data\emo_dyn\Sadness.csv",index_col=[0])
surprise=pd.read_csv(r"C:\Users\WELCOME\Downloads\data\emo_dyn\Surprise.csv",index_col=[0])

# %%
print(anger.shape,trust.shape,anti.shape,disgust.shape,fear.shape,joy.shape,negative.shape,positive.shape,sad.shape,surprise.shape)
# Out:
# (7791, 14) (7791, 14) (7791, 14) (7791, 14) (7791, 14) (7791, 14) (7791, 14) (7791, 14) (7791, 14) (7791, 14)

# %%
anger.head()
# Out:
#                                                          text  \
# Unnamed: 0
# 0           New COVID variant grow rapidly England Andrew ...
# 1           Cookies GOVUK We use essential cooky make webs...
# 2           Covid Nailbiting week ahead NHS hospital Engla...
# 3           Hospitals across UK must prepare Covid surge s...
# 4           Covid Scotland New strain virus accelerate spr...
#
#                                      date  \
# Unnamed: 0
# 0           Thu, 31 Dec 2020 08:00:00 GMT
# 1           Thu, 31 Dec 2020 08:00:00 GMT
# 2           Fri, 01 Jan 2021 08:00:00 GMT
# 3           Sat, 02 Jan 2021 08:00:00 GMT
# 4           Fri, 01 Jan 2021 08:00:00 GMT
#
#                                                          link  \
# Unnamed: 0
# 0           https://www.imperial.ac.uk/news/211793/new-cov...
# 1           https://www.gov.uk/guidance/if-you-need-to-sel...
# 2                        https://www.bbc.com/news/uk-55505722
# ...

# %%
print(anger.shape)
anger.head()
# Out:
# (7791, 14)
#                                                          text  \
# Unnamed: 0
# 0           New COVID variant grow rapidly England Andrew ...
# 1           Cookies GOVUK We use essential cooky make webs...
# 2           Covid Nailbiting week ahead NHS hospital Engla...
# 3           Hospitals across UK must prepare Covid surge s...
# 4           Covid Scotland New strain virus accelerate spr...
#
#                                      date  \
# Unnamed: 0
# 0           Thu, 31 Dec 2020 08:00:00 GMT
# 1           Thu, 31 Dec 2020 08:00:00 GMT
# 2           Fri, 01 Jan 2021 08:00:00 GMT
# 3           Sat, 02 Jan 2021 08:00:00 GMT
# 4           Fri, 01 Jan 2021 08:00:00 GMT
#
#                                                          link  \
# Unnamed: 0
# 0           https://www.imperial.ac.uk/news/211793/new-cov...
# 1           https://www.gov.uk/guidance/if-you-need-to-sel...
# 2                        https://www.bbc.com/news/uk-55505722
# ...

# %%
trust=trust.drop_duplicates(subset=['text','date','link','title','speaker','check_val','polarity','art_len','word_count','pol_tb','numTokens','numLexTokens','lexRatio'])
anti=anti.drop_duplicates(subset=['text','date','link','title','speaker','check_val','polarity','art_len','word_count','pol_tb','numTokens','numLexTokens','lexRatio'])
disgust=disgust.drop_duplicates(subset=['text','date','link','title','speaker','check_val','polarity','art_len','word_count','pol_tb','numTokens','numLexTokens','lexRatio'])
anger=anger.drop_duplicates(subset=['text','date','link','title','speaker','check_val','polarity','art_len','word_count','pol_tb','numTokens','numLexTokens','lexRatio'])
fear=fear.drop_duplicates(subset=['text','date','link','title','speaker','check_val','polarity','art_len','word_count','pol_tb','numTokens','numLexTokens','lexRatio'])
sad=sad.drop_duplicates(subset=['text','date','link','title','speaker','check_val','polarity','art_len','word_count','numTokens','pol_tb','numLexTokens','lexRatio'])
surprise=surprise.drop_duplicates(subset=['text','date','link','title','speaker','check_val','polarity','art_len','word_count','pol_tb','numTokens','numLexTokens','lexRatio'])
positive=positive.drop_duplicates(subset=['text','date','link','title','speaker','check_val','polarity','art_len','word_count','pol_tb','numTokens','numLexTokens','lexRatio'])
negative=negative.drop_duplicates(subset=['text','date','link','title','speaker','check_val','polarity','art_len','word_count','pol_tb','numTokens','numLexTokens','lexRatio'])

# %%
tr_ant=pd.merge(trust,anti,on=['text','date','link','title','speaker','check_val','polarity','art_len','word_count','pol_tb','numTokens','numLexTokens','lexRatio'],suffixes=['_trust',"_anti"])
tr_ant_an=pd.merge(tr_ant,anger,on=['text','date','link','title','speaker','check_val','polarity','art_len','word_count','pol_tb','numTokens','numLexTokens','lexRatio'])
tr_ant_an_di=pd.merge(tr_ant_an,disgust,on=['text','date','link','title','speaker','check_val','polarity','art_len','word_count','pol_tb','numTokens','numLexTokens','lexRatio'],suffixes=['_anger','_disgust'])
tr_ant_an_di_fe=pd.merge(tr_ant_an_di,fear,on=['text','date','link','title','speaker','check_val','polarity','art_len','word_count','pol_tb','numTokens','numLexTokens','lexRatio'])
tr_ant_an_di_fe_jo=pd.merge(tr_ant_an_di_fe,joy,on=['text','date','link','title','speaker','check_val','polarity','art_len','word_count','pol_tb','numTokens','numLexTokens','lexRatio'],suffixes=["_fear","_joy"])
tr_ant_an_di_fe_jo_pos=pd.merge(tr_ant_an_di_fe_jo,positive,on=['text','date','link','title','speaker','check_val','polarity','art_len','word_count','pol_tb','numTokens','numLexTokens','lexRatio'])
tr_ant_an_di_fe_jo_pos_neg=pd.merge(tr_ant_an_di_fe_jo_pos,negative,on=['text','date','link','title','speaker','check_val','polarity','art_len','word_count','pol_tb','numTokens','numLexTokens','lexRatio'],suffixes=["_pos","_neg"])
tr_ant_an_di_fe_jo_pos_neg_sad=pd.merge(tr_ant_an_di_fe_jo_pos_neg,sad,on=['text','date','link','title','speaker','check_val','polarity','art_len','word_count','pol_tb','numTokens','numLexTokens','lexRatio'])
tr_ant_an_di_fe_jo_pos_neg_sad_sur=pd.merge(tr_ant_an_di_fe_jo_pos_neg_sad,surprise,on=['text','date','link','title','speaker','check_val','polarity','art_len','word_count','pol_tb','numTokens','numLexTokens','lexRatio'],suffixes=["_sad","_sur"])

# %%
tr_ant_an_di_fe_jo_pos_neg_sad_sur.shape
# Out:
# (7791, 23)

# %%
emo_data_merged=tr_ant_an_di_fe_jo_pos_neg_sad_sur.copy()

# %%
emo_data_merged.copy()
# Out:
#                                                    text  \
# 0     New COVID variant grow rapidly England Andrew ...
# 1     Cookies GOVUK We use essential cooky make webs...
# 2     Covid Nailbiting week ahead NHS hospital Engla...
# 3     Hospitals across UK must prepare Covid surge s...
# 4     Covid Scotland New strain virus accelerate spr...
# ...                                                 ...
# 7786  Bloomberg Weve detect unusual activity compute...
# 7787  Covid Lancashire health bos use poster make da...
# 7788  ‘ How fair hospital bed take unvaccinated life...
# 7789  Bristol Covid case rise sharply Omicron varian...
# 7790  Football Aberdeen chairman Dave Cormack say ne...
#
#                                date  \
# 0     Thu, 31 Dec 2020 08:00:00 GMT
# 1     Thu, 31 Dec 2020 08:00:00 GMT
# 2     Fri, 01 Jan 2021 08:00:00 GMT
# 3     Sat, 02 Jan 2021 08:00:00 GMT
# 4     Fri, 01 Jan 2021 08:00:00 GMT
# ...                             ...
# ...

# %%
def find_range(colname):
    print("range={} to {}".format(min(emo_data_merged[str(colname)]),max(emo_data_merged[str(colname)])))

# %%
for i in emo_data_merged.columns[6:]:
    print(i)
    find_range(i)
# Out:
# polarity
# range=-0.5249999999999999 to 0.4670454545454545
# art_len
# range=34 to 92541
# word_count
# range=6 to 12432
# pol_tb
# range=negative to positive
# numTokens
# range=6 to 12281
# numLexTokens
# range=1 to 8037
# avgLexVal_trust
# range=0.0 to 1.0
# lexRatio
# range=0.1312154696132596 to 0.75
# avgLexVal_anti
# range=0.0 to 0.4285714285714285
# avgLexVal_anger
# range=0.0 to 0.2205882352941176
# avgLexVal_disgust
# range=0.0 to 0.1944444444444444
# avgLexVal_fear
# range=0.0 to 0.5448275862068965
# avgLexVal_joy
# range=0.0 to 0.2162162162162162
# avgLexVal_pos
# range=0.0 to 1.0
# avgLexVal_neg
# range=0.0 to 0.5632183908045977
# avgLexVal_sad
# range=0.0 to 0.5402298850574713
# avgLexVal_sur
# range=0.0 to 0.2222222222222222

# %%
overall_emo=emo_data_merged[['avgLexVal_trust',"avgLexVal_anti","avgLexVal_anger","avgLexVal_disgust","avgLexVal_fear","avgLexVal_joy","avgLexVal_sad","avgLexVal_sur"]].idxmax(axis=1)

# %%
emo_data_merged=pd.concat([emo_data_merged,overall_emo],axis=1)
emo_data_merged.head(3)
# Out:
#                                                 text  \
# 0  New COVID variant grow rapidly England Andrew ...
# 1  Cookies GOVUK We use essential cooky make webs...
# 2  Covid Nailbiting week ahead NHS hospital Engla...
#
#                             date  \
# 0  Thu, 31 Dec 2020 08:00:00 GMT
# 1  Thu, 31 Dec 2020 08:00:00 GMT
# 2  Fri, 01 Jan 2021 08:00:00 GMT
#
#                                                 link  \
# 0  https://www.imperial.ac.uk/news/211793/new-cov...
# 1  https://www.gov.uk/guidance/if-you-need-to-sel...
# 2               https://www.bbc.com/news/uk-55505722
#
#                                                title speaker  check_val  \
# 0  New COVID-19 variant growing rapidly in Englan...      UK      False
# 1  [Withdrawn] If you need to self-isolate or can...      UK      False
# 2  Covid: 'Nail-biting' weeks ahead for NHS, hosp...      UK      False
#
#    polarity  art_len  word_count    pol_tb  ...  avgLexVal_anti  \
# ...

# %%
emo_data_merged.columns=['text','date','link','title','speaker','check_val','polarity','art_len','word_count','pol_tb','numTokens','numLexTokens','avgLexVal_trust',"lexRatio","avgLexVal_anti","avgLexVal_anger","avgLexVal_disgust","avgLexVal_fear","avgLexVal_joy","avgLexVal_pos","avgLexVal_neg","avgLexVal_sad","avgLexVal_sur","overall_emo"]

# %%
emo_data_merged.head()
# Out:
#                                                 text  \
# 0  New COVID variant grow rapidly England Andrew ...
# 1  Cookies GOVUK We use essential cooky make webs...
# 2  Covid Nailbiting week ahead NHS hospital Engla...
# 3  Hospitals across UK must prepare Covid surge s...
# 4  Covid Scotland New strain virus accelerate spr...
#
#                             date  \
# 0  Thu, 31 Dec 2020 08:00:00 GMT
# 1  Thu, 31 Dec 2020 08:00:00 GMT
# 2  Fri, 01 Jan 2021 08:00:00 GMT
# 3  Sat, 02 Jan 2021 08:00:00 GMT
# 4  Fri, 01 Jan 2021 08:00:00 GMT
#
#                                                 link  \
# 0  https://www.imperial.ac.uk/news/211793/new-cov...
# 1  https://www.gov.uk/guidance/if-you-need-to-sel...
# 2               https://www.bbc.com/news/uk-55505722
# 3             https://www.bbc.co.uk/news/uk-55514363
# 4      https://www.bbc.com/news/uk-scotland-55508141
#
#                                                title speaker  check_val  \
# ...

# %%
overall_emo_text=emo_data_merged.overall_emo.str.cat(sep=' ')

# %% [markdown]
# ## Word clouds from texts of top emotions

# %%
wordcl = WordCloud(stopwords =STOPWORDS, background_color='white', max_font_size = 50, max_words = 5000).generate(overall_emo_text)
plt.figure(figsize=(14, 12))
plt.imshow(wordcl, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
emo_data_merged['overall_emo'].nunique()
# Out:
# 7

# %%
values,counts=np.unique(emo_data_merged['overall_emo'],return_counts=True)
for i in range(len(values)):
    print(values[i]+" "+str(counts[i]))
# Out:
# avgLexVal_anger 15
# avgLexVal_anti 803
# avgLexVal_disgust 4
# avgLexVal_fear 1920
# avgLexVal_joy 7
# avgLexVal_sad 205
# avgLexVal_trust 4837

# %%
trust_text=emo_data_merged[emo_data_merged.overall_emo=='avgLexVal_trust'].text.str.cat(sep=' ')

# %%
wordcl = WordCloud(stopwords = STOPWORDS, background_color='white', max_font_size = 50, max_words = 5000).generate(trust_text)
plt.figure(figsize=(14, 12))
plt.imshow(wordcl, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
fear_text=emo_data_merged[emo_data_merged.overall_emo=='avgLexVal_fear'].text.str.cat(sep=' ')

# %%
wordcl = WordCloud(stopwords = STOPWORDS, background_color='white', max_font_size = 50, max_words = 5000).generate(fear_text)
plt.figure(figsize=(14, 12))
plt.imshow(wordcl, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# # Word clouds by polarity

# %%
overall_pol=emo_data_merged[['avgLexVal_pos',"avgLexVal_neg",]].idxmax(axis=1)
overall_pol
# Out:
# 0       avgLexVal_pos
# 1       avgLexVal_pos
# 2       avgLexVal_pos
# 3       avgLexVal_pos
# 4       avgLexVal_neg
#             ...
# 7786    avgLexVal_pos
# 7787    avgLexVal_pos
# 7788    avgLexVal_neg
# 7789    avgLexVal_neg
# 7790    avgLexVal_pos
# Length: 7791, dtype: object

# %%
emo_data_merged=pd.concat([emo_data_merged,overall_pol],axis=1)
emo_data_merged.columns=['text','date','link','title','speaker','check_val','polarity','art_len','word_count','pol_tb','numTokens','numLexTokens','avgLexVal_trust',"lexRatio","avgLexVal_anti","avgLexVal_anger","avgLexVal_disgust","avgLexVal_fear","avgLexVal_joy","avgLexVal_pos","avgLexVal_neg","avgLexVal_sad","avgLexVal_sur","overall_emo","overall_pol"]

# %%
emo_data_merged.head()
# Out:
#                                                 text  \
# 0  New COVID variant grow rapidly England Andrew ...
# 1  Cookies GOVUK We use essential cooky make webs...
# 2  Covid Nailbiting week ahead NHS hospital Engla...
# 3  Hospitals across UK must prepare Covid surge s...
# 4  Covid Scotland New strain virus accelerate spr...
#
#                             date  \
# 0  Thu, 31 Dec 2020 08:00:00 GMT
# 1  Thu, 31 Dec 2020 08:00:00 GMT
# 2  Fri, 01 Jan 2021 08:00:00 GMT
# 3  Sat, 02 Jan 2021 08:00:00 GMT
# 4  Fri, 01 Jan 2021 08:00:00 GMT
#
#                                                 link  \
# 0  https://www.imperial.ac.uk/news/211793/new-cov...
# 1  https://www.gov.uk/guidance/if-you-need-to-sel...
# 2               https://www.bbc.com/news/uk-55505722
# 3             https://www.bbc.co.uk/news/uk-55514363
# 4      https://www.bbc.com/news/uk-scotland-55508141
#
#                                                title speaker  check_val  \
# ...

# %%
values,counts=np.unique(emo_data_merged['overall_pol'],return_counts=True)
for i in range(len(values)):
    print(values[i]+" "+str(counts[i]))
# Out:
# avgLexVal_neg 1642
# avgLexVal_pos 6149

# %%
emo_data=emo_data_merged.copy()
emo_data.head()
# Out:
#                                                 text  \
# 0  New COVID variant grow rapidly England Andrew ...
# 1  Cookies GOVUK We use essential cooky make webs...
# 2  Covid Nailbiting week ahead NHS hospital Engla...
# 3  Hospitals across UK must prepare Covid surge s...
# 4  Covid Scotland New strain virus accelerate spr...
#
#                             date  \
# 0  Thu, 31 Dec 2020 08:00:00 GMT
# 1  Thu, 31 Dec 2020 08:00:00 GMT
# 2  Fri, 01 Jan 2021 08:00:00 GMT
# 3  Sat, 02 Jan 2021 08:00:00 GMT
# 4  Fri, 01 Jan 2021 08:00:00 GMT
#
#                                                 link  \
# 0  https://www.imperial.ac.uk/news/211793/new-cov...
# 1  https://www.gov.uk/guidance/if-you-need-to-sel...
# 2               https://www.bbc.com/news/uk-55505722
# 3             https://www.bbc.co.uk/news/uk-55514363
# 4      https://www.bbc.com/news/uk-scotland-55508141
#
#                                                title speaker  check_val  \
# ...

# %%
def get_top_n_words(corpus, n=None):
    vec = CountVectorizer(stop_words='english').fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

# %% [markdown]
# ## Frequent words as per NRC postive texts

# %%
pos_text=emo_data[emo_data['overall_pol']=='avgLexVal_pos']['text'].str.cat(sep=' ')
len(pos_text)
# Out:
# 25260220

# %%
print("Frequent Words positive text")
common_words = get_top_n_words(emo_data[emo_data.pol_tb=='positive'].text, 20)
total=len(emo_data[emo_data.pol_tb=='positive'].text)

for word, freq in common_words:

    print(word, freq)
    
    total=total+freq
for word, freq in common_words:
    perc=(freq/len(pos_text)*100)
    print(word,str(perc)+"%")
df1 = pd.DataFrame(common_words, columns = ['ReviewText' , 'count'])
df1.groupby('ReviewText').sum()['count'].sort_values(ascending=False).iplot(
    kind='bar', yTitle='Count', linecolor='black', title='Top 20 words  from positive corpus')
# Out:
# Frequent Words positive text
# covid 57690
# say 42255
# people 34572
# vaccine 30183
# case 22257
# health 20206
# test 19479
# uk 16587
# new 16030
# government 14846
# use 14164
# make 13322
# pandemic 13278
# week 12872
# country 12564
# work 12460
# virus 12235
# year 12032
# day 12027
# number 11794
# covid 0.22838280901749866%
# say 0.16727882813372172%
# people 0.13686341607476102%
# vaccine 0.11948827049012242%
# case 0.08811087156010518%
# health 0.07999138566489128%
# test 0.07711334263913774%
# uk 0.06566451123545242%
# new 0.06345946314006767%
# government 0.05877225138973453%
# use 0.056072354080843316%
# make 0.05273904977866385%
# pandemic 0.05256486285550958%
# week 0.050957592610040604%
# country 0.0497382841479607%
# work 0.04932656960232334%
# virus 0.04843584101801172%
# year 0.04763220589527724%
# day 0.04761241192673698%
# number 0.046690012992760946%
# ...

# %%
neg_text=emo_data[emo_data['overall_pol']=='avgLexVal_neg']['text'].str.cat(sep=' ')
len(neg_text)
# Out:
# 5767078

# %%
print("Frequent Words negative text")
common_words = get_top_n_words(emo_data[emo_data.pol_tb=='negative'].text, 20)
total=0
for word, freq in common_words:

    print(word, freq)
    
    total=total+freq
for word, freq in common_words:
    perc=(freq/len(neg_text))*100
    print(word,str(perc)+"%")
df1 = pd.DataFrame(common_words, columns = ['ReviewText' , 'count'])
df1.groupby('ReviewText').sum()['count'].sort_values(ascending=False).iplot(
    kind='bar', yTitle='Count', linecolor='black', title='Top 20 words  from negative corpus')
# Out:
# Frequent Words negative text
# covid 4458
# say 2177
# people 1907
# case 1837
# test 1363
# health 1236
# vaccine 1066
# day 1047
# uk 1019
# week 995
# data 970
# new 918
# death 910
# pandemic 897
# infection 826
# rate 785
# number 777
# report 743
# government 739
# virus 730
# covid 0.07730084455247528%
# say 0.03774875248782832%
# people 0.033067005509549205%
# case 0.031853219255921286%
# test 0.023634152338497937%
# health 0.021431997278344425%
# vaccine 0.018484230662390903%
# day 0.01815477439354904%
# uk 0.01766925989209787%
# week 0.017253104605139725%
# data 0.016819609514558326%
# new 0.01591793972614901%
# death 0.015779221297162967%
# pandemic 0.015553803850060636%
# infection 0.01432267779280946%
# rate 0.013611745844255965%
# number 0.013473027415269916%
# report 0.012883474092079211%
# government 0.012814114877586187%
# virus 0.012658056644976884%
# ...

# %% [markdown]
# ## Frequent Wordsfor trust corpus

# %%
print("Frequent Words trust text")
common_words = get_top_n_words(emo_data[emo_data.overall_emo=='avgLexVal_trust'].text, 20)
total=0
for word, freq in common_words:

    print(word, freq)
    
    total=total+freq
for word, freq in common_words:
    perc=(freq/len(trust_text))*100
    print(word,str(perc)+"%")
df1 = pd.DataFrame(common_words, columns = ['ReviewText' , 'count'])
df1.groupby('ReviewText').sum()['count'].sort_values(ascending=False).iplot(
    kind='bar', yTitle='Count', linecolor='black', title='Top 20 words  from trust corpus')
# Out:
# Frequent Words trust text
# covid 35231
# say 27199
# vaccine 21438
# people 20515
# health 13815
# test 13715
# use 11212
# case 10517
# government 10334
# uk 10138
# new 9476
# make 9328
# work 8991
# pandemic 8298
# data 8248
# country 7883
# vaccination 7698
# week 7670
# need 7540
# year 7435
# covid 0.1793124319231402%
# say 0.13843259731138743%
# vaccine 0.10911129163430729%
# people 0.10441357159612902%
# health 0.07031311194738106%
# test 0.06980414986307137%
# use 0.05706482889280032%
# case 0.05352754240684811%
# government 0.052596141792561404%
# uk 0.051598576107314456%
# new 0.04822924710918443%
# make 0.04747598322440612%
# work 0.045760781000282524%
# pandemic 0.042233673756016506%
# data 0.04197919271386167%
# country 0.04012148110613137%
# vaccination 0.03917990125015848%
# week 0.03903739186655177%
# need 0.038375741156949195%
# year 0.03784133096842404%
# ...

# %% [markdown]
# ## Top Bigrams for trust corpus

# %%
def get_top_n_bigram(corpus, n=None):
    vec = CountVectorizer(ngram_range=(2, 2),stop_words='english').fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

# %%
print("Frequent Bigrams for trust corpus")
common_words = get_top_n_bigram(emo_data[emo_data.overall_emo=='avgLexVal_trust'].text, 20)
total=0
for word, freq in common_words:

    print(word, freq)
    
    total=total+freq
for word, freq in common_words:
    perc=(freq/len(trust_text))*100
    print(word,str(perc)+"%")
df3 = pd.DataFrame(common_words, columns = ['ReviewText' , 'count'])
df3.groupby('ReviewText').sum()['count'].sort_values(ascending=False).iplot(
    kind='bar', yTitle='Count', linecolor='black', title='Top 20 bigrams for trust corpus')
# Out:
# Frequent Bigrams for trust corpus
# covid vaccine 4148
# public health 3024
# email address 1929
# test positive 1798
# covid case 1491
# prime minister 1329
# film tonight 1309
# covid pandemic 1194
# covid test 1145
# external site 1130
# social care 1115
# bbc news 1106
# covid vaccination 1051
# new variant 1017
# care home 998
# wed like 989
# fully vaccinate 979
# vaccination programme 964
# million people 948
# delta variant 946
# covid vaccine 0.021111747257165154%
# public health 0.015391013429524451%
# email address 0.009817878606333555%
# test positive 0.009151138275887885%
# covid case 0.0075886246770571954%
# prime minister 0.006764106100475528%
# film tonight 0.006662313683613594%
# covid pandemic 0.006077007286657472%
# covid test 0.005827615865345734%
# external site 0.005751271552699283%
# social care 0.005674927240052832%
# bbc news 0.005629120652464962%
# covid vaccination 0.005349191506094643%
# new variant 0.005176144397429355%
# care home 0.005079441601410517%
# ...

# %% [markdown]
# ## Top Words for fear corpus

# %%
print("Frequent Words fear text")
common_words = get_top_n_words(emo_data[emo_data.overall_emo=='avgLexVal_fear'].text, 20)
total=0
for word, freq in common_words:

    print(word, freq)
    
    total=total+freq
for word, freq in common_words:
    perc=(freq/len(fear_text))*100
    print(word,str(perc)+"%")
df1 = pd.DataFrame(common_words, columns = ['ReviewText' , 'count'])
df1.groupby('ReviewText').sum()['count'].sort_values(ascending=False).iplot(
    kind='bar', yTitle='Count', linecolor='black', title='Top 20 words  from fear corpus')
# Out:
# Frequent Words fear text
# covid 16888
# say 11834
# people 10899
# case 10543
# vaccine 6559
# death 5600
# uk 5415
# new 5359
# infection 5149
# health 5044
# test 4343
# number 4262
# week 4238
# pandemic 4228
# virus 4191
# rate 4183
# government 4166
# variant 4164
# day 4130
# country 3858
# covid 0.22363721403755218%
# say 0.15671025526530039%
# people 0.14432863546869265%
# case 0.13961435028410188%
# vaccine 0.08685673181385035%
# death 0.07415729503850618%
# uk 0.07170745582741267%
# new 0.07096588287702761%
# infection 0.06818498431308362%
# health 0.06679453503111163%
# test 0.057511630777184346%
# number 0.05643899847394881%
# week 0.05612118149521235%
# pandemic 0.055988757754072166%
# virus 0.055498789911853454%
# rate 0.055392850918941305%
# government 0.05516773055900298%
# variant 0.055141245810774946%
# day 0.054691005090898304%
# country 0.05108907933188514%
# ...

# %% [markdown]
# ## Top Bigrams for fear corpus

# %%
common_words = get_top_n_bigram(emo_data[emo_data.overall_emo=='avgLexVal_fear'].text, 20)
print("most frequent words for fear corpus")
total=0
for word, freq in common_words:

    print(word, freq)
    
    total=total+freq
for word, freq in common_words:
    perc=(freq/len(fear_text))*100
    print(word,str(perc)+"%")
df4 = pd.DataFrame(common_words, columns = ['ReviewText' , 'count'])
df4.groupby('ReviewText').sum()['count'].sort_values(ascending=False).iplot(
    kind='bar', yTitle='Count', linecolor='black', title='Top 20 bigrams for fear corpus')
# Out:
# most frequent words for fear corpus
# covid case 1472
# covid vaccine 1208
# infection rate 1162
# public health 1124
# new case 1061
# test positive 966
# covid death 668
# delta variant 632
# positive covid 622
# new variant 618
# people die 584
# bbc news 579
# care home 575
# prime minister 557
# seven day 523
# covid infection 512
# fully vaccinate 498
# external site 496
# covid patient 495
# film tonight 492
# covid case 0.019492774695835907%
# covid vaccine 0.015996787929734902%
# infection rate 0.01538763872049003%
# public health 0.014884428504157311%
# new case 0.014050158934974117%
# test positive 0.012792133394142315%
# covid death 0.008845905908164666%
# delta variant 0.008369180440059982%
# positive covid 0.008236756698919793%
# new variant 0.008183787202463717%
# people die 0.007733546482587073%
# bbc news 0.0076673346120169775%
# care home 0.0076143651155609025%
# prime minister 0.00737600238150856%
# seven day 0.006925761661631917%
# ...

# %%
emo_data_merged.to_csv(r"C:\Users\WELCOME\Downloads\data\text_emo_data.csv",index=False)
